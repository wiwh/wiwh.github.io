# %% [raw]
# ---
# title: "GLLVM for longitudinal data"
# author: "Guillaum eBlanc"
# date: "2023-05-15"
# categories: [news, code, analysis]
# ---

# %% [markdown]
# # GLLVM for longitudinal data: a pytorch implementation
#
# We implement a longitudinal GLLVM model with latent variables which follow an AR(1) process through time.

# %% [markdown]
# ## Model Specification
# Let  $y_{i1t},y_{i2t},\ldots,y_{ipt}$  be a set of $p$ response or observed variables at time $t,\ t=1,\ldots,T$ for  individual $i,\ i=1,\ldots,n$. Let $\mathbf{x}_{it}$ be a set of observed $k$-dimensional covariates at time $t,\ t=1,\ldots,T$.
#
# Models for multivariate longitudinal data have to account for the three sources of variability
# present in the data, that is (i) cross-sectional associations between the responses at a particular time point, (ii) cross-lagged
# associations between different responses at different occasions, and  (iii) the association between repeated measures of the same response
# over time. The first source of variability is accounted for
# a time-dependent latent variable $z_{i1}, z_{i2},\ldots,z_{iT}$. Modeling the temporal evolution of the latent variable accounts for the cross-lagged associations between different responses over time.
# The third source of variability can be accounted for a set of item-specific random effects $\mathbf{u}_{i}=(u_{i1}, \ldots, u_{ip})'$.
#
# According to the GLLVM framework we have
#
# \begin{align*}
#    \nonumber y_{ijt}|\mu_{ijt} &\sim \mathcal{F}_j(y_{ijt}\vert \mu_{ijt}, \tau_j)\\
#    \mu_{ijt}&=  g_j(\eta_{ijt})=g_j(\beta_{0jt} + \mathbf{x}_{i}^{\top}\boldsymbol \beta_{jt} + z_{it}^{\top}\lambda_{jt}+u_{ij}\sigma_{u_j})\\ %  \label{eqn:GLLVM-model2}
# \end{align*}
# where $g_j(\cdot),j=1,\ldots,p$ is a known {\it link function}, $\eta_{ijt}=\beta_{0jt} + \mathbf{x}_{i}^{\top}\boldsymbol \beta_{jt} + z_{it}^{\top}\lambda_{jt}+u_{ij},i=1,\ldots,n,j=1,\ldots,p, t=1,\ldots,T$ is the {\it linear predictor},  and $\mathcal{F}_j(y_{ijt}\vert \eta_{ijt}, \tau_j)$ denotes a distribution from the exponential family with mean $\mu_{ijt}$ and response variable-specific dispersion parameter $\tau_j$. \vspace{5pt}\\
# The dynamics of the latent variable over time is modelled through a non-stationary autoregressive model of first order
#
# \begin{equation*}
# z_{it}=\phi z_{i,t-1} + \delta_{it}
# \end{equation*}
# where  $z_{i1}\sim N(0,\sigma^2_{1})$ and $\delta_{it}\sim N(0,1)$.  Moreover, we assume the random effects independent of the latent variable and their common distribution $\mathbf{u}_{i}\sim N_p(\mathbf{0}, \boldsymbol I)$.
#
#
#
# ## Measurement invariance
#
# The  latent variable $z_{it}$ has to be the same (same meaning) across occasions.
# Thus the measurement invariance assumption has to be tested on the data, that is
# all the measurement parameters  are invariant across occasions, that is $$\beta_{0jt}=\beta_{0j} \ \textrm{and } \ \lambda_{jt}=
# \lambda_{j},$$ for all $t$, $t=1, \ldots, T$ and for all $j$, $j=1,\ldots, p$.
# Under this assumption, the model is more parsimonious  and avoids some possible identification problem that might arise with
# increasing the number of time points.
#
# To ensure identification of the model, one necessary condition is that the latent variable has a scale and an origin. %When measurement
# %invariance of loadings and intercepts is imposed,
# Scale for  $z_{it}$  can be provided either by fixing one loading at a nonzero value or by
# fixing the factor variance at a nonzero value. In presence of longitudinal data, the same loading is fixed equal to one at each occasion.

# %% [markdown]
# ## Implementation using Pytorch
#
# We model each observation as a tuple of dimension `(T, p)`, common across individuals. Individuals constitute independent observations, which yields the tensor structure `(n, T, q)`. The time dimension `T` appears in the first dimension since it allows for seamless tensor products of the type `(n, T, q) (q, p)`.
#
# Elements we need:
#
# * A model that defines the generative process
# * A loss function which, upon taking the derivative, re-creates the estimating equations
# * A way to compute the latent variables. For now, we will use a neural network. Later, we can implement the real function.

# %%
import torch
from torch import nn
import numpy as np
import math
import matplotlib.pyplot as plt

n = 100
p = 15
T = 20
k = 8
q = 1

DIMENSIONS_Y = (n, T, p) 
DIMENSIONS_X = (n, T, k)
DIMENSIONS_Z = (n, T, q)
DIMENSIONS_U = (n, 1, p)

# TODO: refactor to have a module of two modules: encoder and decoder
class GLLVM_longitudinal():
    def __init__(self):
        self.encoder = Encoder()
        self.decoder = Decoder()

        # nuisance parameters
        self.phi = torch.ones(1) * .3
        self.var_u = torch.ones((1,1,p))
        self.var_y = torch.ones((1,1,p))
        self.var_z = torch.ones((1,T,1))

    def encoder_fit(self, x, y, z, u, epochs=100, verbose=False):
        encoder_loss = nn.MSELoss()
        encoder_opt = torch.optim.Adam(self.encoder.parameters())
        for epoch in range(epochs):
            (zhat, uhat) = self.encoder(x, y)
            loss = self.encoder_loss(zhat, z) + encoder_loss(uhat, u)
            if verbose:
                print(f"\nEpoch {epoch}/{epochs}, loss={loss}")
            loss.backward()
            encoder_opt.step()
            encoder_opt.zero_grad()
        return loss

    def encoder_loss(self, input_z, target_z):
        # here we penalize the variances too !!
        phi_input = (torch.sum(input_z[:,1:]*input_z[:,:(T-1)], dim=1) / torch.sum(torch.pow(input_z[:,:(T-1)],2), dim=1)).mean()
        phi_target = (torch.sum(target_z[:,1:]*target_z[:,:(T-1)], dim=1) / torch.sum(torch.pow(target_z[:,:(T-1)],2), dim=1)).mean()
        return torch.sum(pow(input_z-target_z, 2), dim=[1,2]).mean() + 1e4*pow(phi_input-phi_target, 2)

    def update_nuisance_parameters(self, z_sample, u_sample, z_sim, u_sim, lr=1e-1):
        # update phi:
        # phi_sample = torch.sum(z_sample[:,1:]*z_sample[:,:(T-1)], dim=1) # - self.phi* torch.sum(torch.pow(z_sample[:,:(T-1)],2), dim=1)
        # phi_sim = torch.sum(z_sim[:,1:]*z_sim[:,:(T-1)], dim=1) #- self.phi * torch.sum(torch.pow(z_sim[:,:(T-1)],2), dim=1)
        # self.phi = self.phi + lr * (math.sqrt(phi_sample.mean()) - math.sqrt(phi_sim.mean()))
        phi_sample = torch.sum(z_sample[:,1:]*z_sample[:,:(T-1)], dim=1) / torch.sum(torch.pow(z_sample[:,:(T-1)],2), dim=1)
        phi_sim = torch.sum(z_sim[:,1:]*z_sim[:,:(T-1)], dim=1) / torch.sum(torch.pow(z_sim[:,:(T-1)],2), dim=1)
        # var_u = torch.mean(torch.pow(u_sample, 2), dim=0)

        self.phi = self.phi  + lr * (phi_sample.mean() - phi_sim.mean())
        #self.var_u = self.var_u * (1-lr) + lr * var_u


    def sample(self, n, x=None, z=None, u=None, d=None):
        """Sample a longitudinal GLLVM, potentially with z, u, and d(elta), and return (x, z, u, d, y)"""

        with torch.no_grad():
            if x is None:
                Warning("xb was set to None for sampling. This is usually unwanted unless k=0.")
                x = torch.randn((n, T, k))
            if z is None:
                z = torch.randn((n, T, q)) * torch.sqrt(self.var_z)

            if d is None:
                d = torch.randn((n, T, q))
        
            if u is None:
                u = torch.randn((n, 1, p)) * torch.sqrt(self.var_u)
        
            z = self.AR(z, d)

            eps = torch.randn((n, T, p)) * torch.sqrt(self.var_y)
            y = self.decoder(x, z, u) + eps

        return {"x":x, "z":z, "u":u, "d":d, "y":y}
    
    def AR(self, z, delta):
        assert z.shape == delta.shape  # we draw the same shape for simplicity, even though we don't need delta for t=0.
        for t in range(1, z.shape[1]):
            z[:,t] = z[:, t-1] * self.phi + delta[:,t]
        return z

    def sample_z(self):
        return None

class Decoder(nn.Module):
    def __init__(self):
        super().__init__()

        # decoder part (our parameters of interest)
        self.wz = nn.Parameter(torch.randn((q, p)))
        self.wx = nn.Parameter(torch.randn((T, k, p)))
        self.bias = torch.zeros((1, T, p))

    # decoding
    def forward(self, x, z, u):
        xwx = (x.unsqueeze(2) @ self.wx).squeeze() # see details of tensorproducts
        zwz = (z.unsqueeze(2) @ self.wz).squeeze()
        linpar = self.bias + xwx + zwz + u 
        return linpar


class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        # encoder part
        # input dimension is T * (p+k)... we buuild a fully connected layer but it isn't necessary 
        # output dimension is T*q  + p (for Z and U, respectively)
        self.enc_model = nn.Sequential(
            nn.Linear(in_features=T*(p+k), out_features = 100),
            nn.ReLU(),
            nn.Linear(in_features=100, out_features = 100),
            nn.ReLU(),
            nn.Linear(in_features=100, out_features = 100),
            nn.ReLU(),
            nn.Linear(in_features=100, out_features = T*q + p)
        )
    
    def forward(self, x, y):
        xy = torch.cat([x, y], dim=2).flatten(start_dim=1)
        zu = self.enc_model(xy)
        return self.split_zu(zu)

    def split_zu(self, zu):
        #output dimension of size (T*Z), p
        z, u = torch.split(zu, [T*q, p], dim=1)
        z = z.reshape((z.shape[0], T, q))
        u = u.unsqueeze(1)
        return (z, u)

class Nuisance(nn.Module):
    def __init__(self):
        super().__init__()

        self.enc_model = nn.Sequential(
            nn.Linear(in_features=(T-1)*q + p, out_features = 50), # T-1 because we devide T+1 by T (feature engineering)
            nn.ReLU(),
            nn.Linear(in_features=50, out_features = 50),
            nn.ReLU(),
            # phi is 1 dimensional, var_u is p-dimensional, var_y is p dimensional (for non-singleton dimensions)
            nn.Linear(1 + p + p)
        )
    
    def forward(self):
        None

# %%
gl_true = GLLVM_longitudinal()
dat_true = gl_true.sample(n)

gl = GLLVM_longitudinal()

# %%
def my_loss(input, target, sign=1):
    return sign * torch.sum(input*target, dim=[1,2]).mean()




def evaluate_fit(input, target):
    with torch.no_grad():
        return torch.sum(torch.pow(input - target,2), dim=[1,2]).mean()

# %%
with torch.no_grad():
    dat_sim = gl.sample(n, x=dat_true["x"]) # x are known and fixed

# train the encoder

gl.encoder_fit(dat_sim["x"], dat_sim["y"], dat_sim["z"], dat_sim["u"], epochs=100)
# Out:
# tensor(23.1854, grad_fn=<AddBackward0>)

# %%
#| output: false
decoder_opt = torch.optim.SGD(gl.decoder.parameters(), lr=1e-2)
# decoder_opt = torch.optim.Adam(gl.decoder.parameters())

epochs = 2000
lr_init = 1e-3
for epoch in range(1, epochs+1):
    lr= lr_init#/math.sqrt(epochs)
    
    with torch.no_grad():
        dat_sim = gl.sample(n, x=dat_true["x"]) # x are known and fixed

    # train the encoder

    encoder_loss = gl.encoder_fit(dat_sim["x"], dat_sim["y"], dat_sim["z"], dat_sim["u"], epochs=10)
    
    # compute SPRIME sample step

    # compute imputing values
    with torch.no_grad():
        zhat_true, uhat_true = gl.encoder(dat_true["x"], dat_true["y"])

    linpar_sample = gl.decoder(dat_true["x"], zhat_true, uhat_true)
    loss = my_loss(linpar_sample, dat_true["y"], sign=-1) #notice the -sign here
    loss.backward()

    # compute SPRIME simulation step
    # compute imputing values
    with torch.no_grad():
        zhat_sim, uhat_sim = gl.encoder(dat_sim["x"], dat_sim["y"])
        
    linpar_sim = gl.decoder(dat_sim["x"], zhat_sim, uhat_sim)
    loss = my_loss(linpar_sim, dat_sim["y"], sign=1)
    loss.backward()

    with torch.no_grad():
        for par in gl.decoder.parameters():
            par -= par.grad * lr
        gl.decoder.zero_grad()

    # Update nuisance parameters
    with torch.no_grad():
        gl.update_nuisance_parameters(zhat_true, uhat_true, zhat_sim, uhat_sim, lr=1e-2)

    # evaluate the model
    if epoch == 1 or epoch % 10 == 0:
        with torch.no_grad():
            loss = evaluate_fit(linpar_sample, dat_true["y"])

        print(f"\nEpoch {epoch}/{epochs}, loss = {loss:.2f}, encoder_loss = {encoder_loss:.2f}, phi= {gl.phi}, var_u ={gl.var_u[0,0,0]}")
# Out:
# Epoch 1/2000, loss = 651.76, encoder_loss = 9.84, phi= tensor([0.2996]), var_u =1.0
#
# Epoch 10/2000, loss = 655.29, encoder_loss = 9.76, phi= tensor([0.3000]), var_u =1.0
#
# Epoch 20/2000, loss = 649.55, encoder_loss = 9.90, phi= tensor([0.3004]), var_u =1.0
#
# Epoch 30/2000, loss = 649.93, encoder_loss = 10.04, phi= tensor([0.3000]), var_u =1.0
#
# Epoch 40/2000, loss = 661.69, encoder_loss = 13.19, phi= tensor([0.3003]), var_u =1.0
#
# Epoch 50/2000, loss = 645.71, encoder_loss = 10.55, phi= tensor([0.3003]), var_u =1.0
#
# Epoch 60/2000, loss = 646.03, encoder_loss = 10.04, phi= tensor([0.3004]), var_u =1.0
#
# Epoch 70/2000, loss = 644.00, encoder_loss = 9.70, phi= tensor([0.3004]), var_u =1.0
#
# Epoch 80/2000, loss = 647.89, encoder_loss = 9.14, phi= tensor([0.3008]), var_u =1.0
#
# Epoch 90/2000, loss = 652.35, encoder_loss = 11.46, phi= tensor([0.3004]), var_u =1.0
#
# Epoch 100/2000, loss = 650.42, encoder_loss = 11.08, phi= tensor([0.3002]), var_u =1.0
#
# Epoch 110/2000, loss = 641.50, encoder_loss = 9.85, phi= tensor([0.3001]), var_u =1.0
#
# Epoch 120/2000, loss = 642.79, encoder_loss = 8.99, phi= tensor([0.3003]), var_u =1.0
#
# Epoch 130/2000, loss = 642.92, encoder_loss = 9.50, phi= tensor([0.3010]), var_u =1.0
#
# Epoch 140/2000, loss = 641.71, encoder_loss = 9.34, phi= tensor([0.3010]), var_u =1.0
#
# Epoch 150/2000, loss = 643.71, encoder_loss = 10.30, phi= tensor([0.3013]), var_u =1.0
#
# Epoch 160/2000, loss = 639.34, encoder_loss = 9.52, phi= tensor([0.3011]), var_u =1.0
#
# Epoch 170/2000, loss = 642.85, encoder_loss = 8.99, phi= tensor([0.3013]), var_u =1.0
#
# Epoch 180/2000, loss = 637.68, encoder_loss = 10.33, phi= tensor([0.3017]), var_u =1.0
#
# Epoch 190/2000, loss = 636.95, encoder_loss = 10.25, phi= tensor([0.3015]), var_u =1.0
#
# Epoch 200/2000, loss = 638.13, encoder_loss = 11.47, phi= tensor([0.3028]), var_u =1.0
#
# Epoch 210/2000, loss = 636.20, encoder_loss = 9.72, phi= tensor([0.3028]), var_u =1.0
#
# Epoch 220/2000, loss = 635.23, encoder_loss = 8.68, phi= tensor([0.3030]), var_u =1.0
#
# Epoch 230/2000, loss = 636.57, encoder_loss = 8.91, phi= tensor([0.3030]), var_u =1.0
#
# Epoch 240/2000, loss = 632.80, encoder_loss = 8.82, phi= tensor([0.3028]), var_u =1.0
#
# Epoch 250/2000, loss = 634.21, encoder_loss = 9.21, phi= tensor([0.3032]), var_u =1.0
#
# Epoch 260/2000, loss = 628.82, encoder_loss = 10.28, phi= tensor([0.3032]), var_u =1.0
#
# Epoch 270/2000, loss = 633.32, encoder_loss = 9.65, phi= tensor([0.3038]), var_u =1.0
#
# Epoch 280/2000, loss = 629.57, encoder_loss = 9.77, phi= tensor([0.3042]), var_u =1.0
#
# Epoch 290/2000, loss = 632.28, encoder_loss = 9.91, phi= tensor([0.3048]), var_u =1.0
#
# Epoch 300/2000, loss = 633.17, encoder_loss = 9.36, phi= tensor([0.3048]), var_u =1.0
#
# Epoch 310/2000, loss = 626.64, encoder_loss = 8.85, phi= tensor([0.3050]), var_u =1.0
#
# Epoch 320/2000, loss = 631.96, encoder_loss = 12.51, phi= tensor([0.3054]), var_u =1.0
#
# Epoch 330/2000, loss = 631.23, encoder_loss = 11.38, phi= tensor([0.3061]), var_u =1.0
#
# Epoch 340/2000, loss = 626.32, encoder_loss = 9.21, phi= tensor([0.3064]), var_u =1.0
#
# Epoch 350/2000, loss = 623.66, encoder_loss = 9.75, phi= tensor([0.3073]), var_u =1.0
#
# Epoch 360/2000, loss = 622.30, encoder_loss = 9.20, phi= tensor([0.3082]), var_u =1.0
#
# Epoch 370/2000, loss = 623.84, encoder_loss = 9.32, phi= tensor([0.3089]), var_u =1.0
#
# Epoch 380/2000, loss = 627.69, encoder_loss = 10.03, phi= tensor([0.3096]), var_u =1.0
#
# Epoch 390/2000, loss = 623.39, encoder_loss = 9.59, phi= tensor([0.3106]), var_u =1.0
#
# Epoch 400/2000, loss = 620.84, encoder_loss = 9.62, phi= tensor([0.3114]), var_u =1.0
#
# Epoch 410/2000, loss = 626.28, encoder_loss = 9.63, phi= tensor([0.3120]), var_u =1.0
#
# Epoch 420/2000, loss = 621.88, encoder_loss = 9.51, phi= tensor([0.3125]), var_u =1.0
#
# Epoch 430/2000, loss = 624.51, encoder_loss = 10.14, phi= tensor([0.3134]), var_u =1.0
#
# Epoch 440/2000, loss = 619.59, encoder_loss = 8.37, phi= tensor([0.3138]), var_u =1.0
#
# Epoch 450/2000, loss = 617.59, encoder_loss = 9.41, phi= tensor([0.3141]), var_u =1.0
#
# Epoch 460/2000, loss = 623.99, encoder_loss = 10.89, phi= tensor([0.3144]), var_u =1.0
#
# Epoch 470/2000, loss = 624.48, encoder_loss = 13.49, phi= tensor([0.3148]), var_u =1.0
#
# Epoch 480/2000, loss = 622.82, encoder_loss = 10.64, phi= tensor([0.3152]), var_u =1.0
#
# Epoch 490/2000, loss = 621.99, encoder_loss = 9.92, phi= tensor([0.3158]), var_u =1.0
#
# Epoch 500/2000, loss = 619.62, encoder_loss = 9.26, phi= tensor([0.3164]), var_u =1.0
#
# Epoch 510/2000, loss = 617.53, encoder_loss = 9.23, phi= tensor([0.3172]), var_u =1.0
#
# Epoch 520/2000, loss = 619.32, encoder_loss = 8.73, phi= tensor([0.3174]), var_u =1.0
#
# Epoch 530/2000, loss = 617.96, encoder_loss = 11.47, phi= tensor([0.3178]), var_u =1.0
#
# Epoch 540/2000, loss = 618.98, encoder_loss = 10.13, phi= tensor([0.3183]), var_u =1.0
#
# Epoch 550/2000, loss = 618.38, encoder_loss = 9.48, phi= tensor([0.3183]), var_u =1.0
#
# Epoch 560/2000, loss = 616.56, encoder_loss = 9.57, phi= tensor([0.3180]), var_u =1.0
#
# Epoch 570/2000, loss = 622.43, encoder_loss = 9.54, phi= tensor([0.3178]), var_u =1.0
#
# Epoch 580/2000, loss = 615.65, encoder_loss = 9.06, phi= tensor([0.3174]), var_u =1.0
#
# Epoch 590/2000, loss = 620.69, encoder_loss = 9.88, phi= tensor([0.3176]), var_u =1.0
#
# Epoch 600/2000, loss = 621.16, encoder_loss = 9.37, phi= tensor([0.3178]), var_u =1.0
#
# Epoch 610/2000, loss = 617.26, encoder_loss = 9.77, phi= tensor([0.3181]), var_u =1.0
#
# Epoch 620/2000, loss = 616.32, encoder_loss = 8.82, phi= tensor([0.3182]), var_u =1.0
#
# Epoch 630/2000, loss = 613.60, encoder_loss = 8.80, phi= tensor([0.3183]), var_u =1.0
#
# Epoch 640/2000, loss = 609.94, encoder_loss = 8.27, phi= tensor([0.3183]), var_u =1.0
#
# Epoch 650/2000, loss = 622.28, encoder_loss = 13.41, phi= tensor([0.3185]), var_u =1.0
#
# Epoch 660/2000, loss = 613.70, encoder_loss = 10.22, phi= tensor([0.3188]), var_u =1.0
#
# Epoch 670/2000, loss = 616.00, encoder_loss = 9.33, phi= tensor([0.3190]), var_u =1.0
#
# Epoch 680/2000, loss = 613.77, encoder_loss = 9.62, phi= tensor([0.3189]), var_u =1.0
#
# Epoch 690/2000, loss = 614.11, encoder_loss = 9.29, phi= tensor([0.3191]), var_u =1.0
#
# Epoch 700/2000, loss = 619.60, encoder_loss = 11.50, phi= tensor([0.3190]), var_u =1.0
#
# Epoch 710/2000, loss = 611.83, encoder_loss = 8.75, phi= tensor([0.3191]), var_u =1.0
#
# Epoch 720/2000, loss = 610.02, encoder_loss = 8.40, phi= tensor([0.3189]), var_u =1.0
#
# Epoch 730/2000, loss = 611.57, encoder_loss = 10.31, phi= tensor([0.3188]), var_u =1.0
#
# Epoch 740/2000, loss = 609.50, encoder_loss = 9.71, phi= tensor([0.3189]), var_u =1.0
#
# Epoch 750/2000, loss = 611.43, encoder_loss = 9.63, phi= tensor([0.3190]), var_u =1.0
#
# Epoch 760/2000, loss = 610.52, encoder_loss = 10.07, phi= tensor([0.3193]), var_u =1.0
#
# Epoch 770/2000, loss = 609.64, encoder_loss = 9.12, phi= tensor([0.3187]), var_u =1.0
#
# Epoch 780/2000, loss = 612.58, encoder_loss = 9.59, phi= tensor([0.3189]), var_u =1.0
#
# Epoch 790/2000, loss = 610.45, encoder_loss = 9.15, phi= tensor([0.3193]), var_u =1.0
#
# Epoch 800/2000, loss = 612.35, encoder_loss = 9.73, phi= tensor([0.3195]), var_u =1.0
#
# Epoch 810/2000, loss = 610.85, encoder_loss = 8.89, phi= tensor([0.3192]), var_u =1.0
#
# Epoch 820/2000, loss = 611.01, encoder_loss = 9.36, phi= tensor([0.3196]), var_u =1.0
#
# Epoch 830/2000, loss = 608.45, encoder_loss = 9.58, phi= tensor([0.3198]), var_u =1.0
#
# Epoch 840/2000, loss = 607.84, encoder_loss = 10.13, phi= tensor([0.3198]), var_u =1.0
#
# Epoch 850/2000, loss = 605.17, encoder_loss = 9.73, phi= tensor([0.3198]), var_u =1.0
#
# Epoch 860/2000, loss = 605.78, encoder_loss = 10.14, phi= tensor([0.3203]), var_u =1.0
#
# Epoch 870/2000, loss = 604.81, encoder_loss = 10.19, phi= tensor([0.3202]), var_u =1.0
#
# Epoch 880/2000, loss = 616.38, encoder_loss = 12.52, phi= tensor([0.3201]), var_u =1.0
#
# Epoch 890/2000, loss = 608.42, encoder_loss = 9.81, phi= tensor([0.3208]), var_u =1.0
#
# Epoch 900/2000, loss = 608.54, encoder_loss = 9.79, phi= tensor([0.3210]), var_u =1.0
#
# Epoch 910/2000, loss = 605.81, encoder_loss = 9.65, phi= tensor([0.3211]), var_u =1.0
#
# Epoch 920/2000, loss = 607.45, encoder_loss = 10.21, phi= tensor([0.3214]), var_u =1.0
#
# Epoch 930/2000, loss = 608.14, encoder_loss = 10.29, phi= tensor([0.3219]), var_u =1.0
#
# Epoch 940/2000, loss = 607.96, encoder_loss = 9.46, phi= tensor([0.3220]), var_u =1.0
#
# Epoch 950/2000, loss = 607.29, encoder_loss = 9.27, phi= tensor([0.3220]), var_u =1.0
#
# Epoch 960/2000, loss = 608.08, encoder_loss = 9.03, phi= tensor([0.3223]), var_u =1.0
#
# Epoch 970/2000, loss = 608.68, encoder_loss = 10.12, phi= tensor([0.3229]), var_u =1.0
#
# Epoch 980/2000, loss = 605.34, encoder_loss = 8.85, phi= tensor([0.3231]), var_u =1.0
#
# Epoch 990/2000, loss = 605.79, encoder_loss = 9.29, phi= tensor([0.3234]), var_u =1.0
#
# Epoch 1000/2000, loss = 604.31, encoder_loss = 10.37, phi= tensor([0.3235]), var_u =1.0
#
# Epoch 1010/2000, loss = 606.02, encoder_loss = 9.70, phi= tensor([0.3238]), var_u =1.0
#
# Epoch 1020/2000, loss = 604.21, encoder_loss = 9.59, phi= tensor([0.3240]), var_u =1.0
#
# Epoch 1030/2000, loss = 604.93, encoder_loss = 9.53, phi= tensor([0.3239]), var_u =1.0
#
# Epoch 1040/2000, loss = 601.34, encoder_loss = 10.36, phi= tensor([0.3239]), var_u =1.0
#
# Epoch 1050/2000, loss = 605.46, encoder_loss = 9.82, phi= tensor([0.3236]), var_u =1.0
#
# Epoch 1060/2000, loss = 608.18, encoder_loss = 9.54, phi= tensor([0.3231]), var_u =1.0
#
# Epoch 1070/2000, loss = 603.97, encoder_loss = 10.54, phi= tensor([0.3234]), var_u =1.0
#
# Epoch 1080/2000, loss = 600.86, encoder_loss = 9.87, phi= tensor([0.3237]), var_u =1.0
#
# Epoch 1090/2000, loss = 606.29, encoder_loss = 9.67, phi= tensor([0.3233]), var_u =1.0
#
# Epoch 1100/2000, loss = 606.76, encoder_loss = 10.66, phi= tensor([0.3238]), var_u =1.0
#
# Epoch 1110/2000, loss = 603.23, encoder_loss = 9.40, phi= tensor([0.3240]), var_u =1.0
#
# Epoch 1120/2000, loss = 604.51, encoder_loss = 9.88, phi= tensor([0.3239]), var_u =1.0
#
# Epoch 1130/2000, loss = 606.12, encoder_loss = 10.01, phi= tensor([0.3239]), var_u =1.0
#
# Epoch 1140/2000, loss = 603.04, encoder_loss = 9.39, phi= tensor([0.3239]), var_u =1.0
#
# Epoch 1150/2000, loss = 604.86, encoder_loss = 9.07, phi= tensor([0.3235]), var_u =1.0
#
# Epoch 1160/2000, loss = 604.08, encoder_loss = 10.32, phi= tensor([0.3234]), var_u =1.0
#
# Epoch 1170/2000, loss = 604.04, encoder_loss = 9.71, phi= tensor([0.3241]), var_u =1.0
#
# Epoch 1180/2000, loss = 602.93, encoder_loss = 9.44, phi= tensor([0.3248]), var_u =1.0
#
# Epoch 1190/2000, loss = 606.59, encoder_loss = 9.05, phi= tensor([0.3250]), var_u =1.0
#
# Epoch 1200/2000, loss = 609.50, encoder_loss = 10.19, phi= tensor([0.3247]), var_u =1.0
#
# Epoch 1210/2000, loss = 604.64, encoder_loss = 9.85, phi= tensor([0.3249]), var_u =1.0
#
# Epoch 1220/2000, loss = 607.37, encoder_loss = 10.17, phi= tensor([0.3243]), var_u =1.0
#
# Epoch 1230/2000, loss = 605.39, encoder_loss = 10.24, phi= tensor([0.3238]), var_u =1.0
#
# Epoch 1240/2000, loss = 615.00, encoder_loss = 11.67, phi= tensor([0.3240]), var_u =1.0
#
# Epoch 1250/2000, loss = 607.24, encoder_loss = 10.03, phi= tensor([0.3238]), var_u =1.0
#
# Epoch 1260/2000, loss = 605.72, encoder_loss = 9.99, phi= tensor([0.3241]), var_u =1.0
#
# Epoch 1270/2000, loss = 602.00, encoder_loss = 9.48, phi= tensor([0.3240]), var_u =1.0
#
# Epoch 1280/2000, loss = 599.30, encoder_loss = 9.67, phi= tensor([0.3237]), var_u =1.0
#
# Epoch 1290/2000, loss = 602.46, encoder_loss = 9.52, phi= tensor([0.3234]), var_u =1.0
#
# Epoch 1300/2000, loss = 605.93, encoder_loss = 9.48, phi= tensor([0.3235]), var_u =1.0
#
# Epoch 1310/2000, loss = 605.99, encoder_loss = 9.14, phi= tensor([0.3232]), var_u =1.0
#
# Epoch 1320/2000, loss = 603.97, encoder_loss = 10.03, phi= tensor([0.3225]), var_u =1.0
#
# Epoch 1330/2000, loss = 613.12, encoder_loss = 9.94, phi= tensor([0.3225]), var_u =1.0
#
# Epoch 1340/2000, loss = 603.70, encoder_loss = 11.51, phi= tensor([0.3221]), var_u =1.0
#
# Epoch 1350/2000, loss = 604.02, encoder_loss = 10.27, phi= tensor([0.3222]), var_u =1.0
#
# Epoch 1360/2000, loss = 602.34, encoder_loss = 9.87, phi= tensor([0.3223]), var_u =1.0
#
# Epoch 1370/2000, loss = 605.25, encoder_loss = 9.77, phi= tensor([0.3223]), var_u =1.0
#
# Epoch 1380/2000, loss = 603.25, encoder_loss = 9.01, phi= tensor([0.3225]), var_u =1.0
#
# Epoch 1390/2000, loss = 601.82, encoder_loss = 9.30, phi= tensor([0.3227]), var_u =1.0
#
# Epoch 1400/2000, loss = 602.07, encoder_loss = 9.42, phi= tensor([0.3225]), var_u =1.0
#
# Epoch 1410/2000, loss = 599.86, encoder_loss = 9.93, phi= tensor([0.3224]), var_u =1.0
#
# Epoch 1420/2000, loss = 606.23, encoder_loss = 10.87, phi= tensor([0.3226]), var_u =1.0
#
# Epoch 1430/2000, loss = 602.86, encoder_loss = 11.41, phi= tensor([0.3229]), var_u =1.0
#
# Epoch 1440/2000, loss = 606.03, encoder_loss = 12.53, phi= tensor([0.3229]), var_u =1.0
#
# Epoch 1450/2000, loss = 600.20, encoder_loss = 9.60, phi= tensor([0.3230]), var_u =1.0
#
# Epoch 1460/2000, loss = 605.78, encoder_loss = 11.99, phi= tensor([0.3235]), var_u =1.0
#
# Epoch 1470/2000, loss = 601.96, encoder_loss = 9.82, phi= tensor([0.3239]), var_u =1.0
#
# Epoch 1480/2000, loss = 599.18, encoder_loss = 9.14, phi= tensor([0.3250]), var_u =1.0
#
# Epoch 1490/2000, loss = 605.35, encoder_loss = 9.76, phi= tensor([0.3252]), var_u =1.0
#
# Epoch 1500/2000, loss = 603.27, encoder_loss = 10.88, phi= tensor([0.3251]), var_u =1.0
#
# Epoch 1510/2000, loss = 601.12, encoder_loss = 8.91, phi= tensor([0.3251]), var_u =1.0
#
# Epoch 1520/2000, loss = 600.85, encoder_loss = 9.31, phi= tensor([0.3260]), var_u =1.0
#
# Epoch 1530/2000, loss = 600.12, encoder_loss = 9.98, phi= tensor([0.3263]), var_u =1.0
#
# Epoch 1540/2000, loss = 604.24, encoder_loss = 11.08, phi= tensor([0.3263]), var_u =1.0
#
# Epoch 1550/2000, loss = 603.40, encoder_loss = 12.00, phi= tensor([0.3262]), var_u =1.0
#
# Epoch 1560/2000, loss = 600.77, encoder_loss = 9.80, phi= tensor([0.3263]), var_u =1.0
#
# Epoch 1570/2000, loss = 604.75, encoder_loss = 10.33, phi= tensor([0.3264]), var_u =1.0
#
# Epoch 1580/2000, loss = 603.22, encoder_loss = 8.82, phi= tensor([0.3261]), var_u =1.0
#
# Epoch 1590/2000, loss = 599.64, encoder_loss = 10.13, phi= tensor([0.3263]), var_u =1.0
#
# Epoch 1600/2000, loss = 601.74, encoder_loss = 9.12, phi= tensor([0.3268]), var_u =1.0
#
# Epoch 1610/2000, loss = 601.37, encoder_loss = 9.43, phi= tensor([0.3267]), var_u =1.0
#
# Epoch 1620/2000, loss = 606.41, encoder_loss = 10.69, phi= tensor([0.3266]), var_u =1.0
#
# Epoch 1630/2000, loss = 599.55, encoder_loss = 9.60, phi= tensor([0.3262]), var_u =1.0
#
# Epoch 1640/2000, loss = 598.29, encoder_loss = 9.28, phi= tensor([0.3258]), var_u =1.0
#
# Epoch 1650/2000, loss = 603.96, encoder_loss = 10.07, phi= tensor([0.3257]), var_u =1.0
#
# Epoch 1660/2000, loss = 599.32, encoder_loss = 8.88, phi= tensor([0.3252]), var_u =1.0
#
# Epoch 1670/2000, loss = 598.33, encoder_loss = 10.07, phi= tensor([0.3252]), var_u =1.0
#
# Epoch 1680/2000, loss = 604.75, encoder_loss = 9.84, phi= tensor([0.3251]), var_u =1.0
#
# Epoch 1690/2000, loss = 603.99, encoder_loss = 9.84, phi= tensor([0.3253]), var_u =1.0
#
# Epoch 1700/2000, loss = 603.62, encoder_loss = 9.93, phi= tensor([0.3251]), var_u =1.0
#
# Epoch 1710/2000, loss = 599.23, encoder_loss = 9.44, phi= tensor([0.3250]), var_u =1.0
#
# Epoch 1720/2000, loss = 601.26, encoder_loss = 10.22, phi= tensor([0.3253]), var_u =1.0
#
# Epoch 1730/2000, loss = 598.12, encoder_loss = 8.95, phi= tensor([0.3256]), var_u =1.0
#
# Epoch 1740/2000, loss = 598.83, encoder_loss = 9.96, phi= tensor([0.3261]), var_u =1.0
#
# Epoch 1750/2000, loss = 600.34, encoder_loss = 9.68, phi= tensor([0.3265]), var_u =1.0
#
# Epoch 1760/2000, loss = 602.85, encoder_loss = 9.38, phi= tensor([0.3265]), var_u =1.0
#
# Epoch 1770/2000, loss = 601.10, encoder_loss = 9.73, phi= tensor([0.3263]), var_u =1.0
#
# Epoch 1780/2000, loss = 607.40, encoder_loss = 13.79, phi= tensor([0.3263]), var_u =1.0
#
# Epoch 1790/2000, loss = 598.62, encoder_loss = 9.56, phi= tensor([0.3271]), var_u =1.0
#
# Epoch 1800/2000, loss = 597.01, encoder_loss = 9.40, phi= tensor([0.3272]), var_u =1.0
#
# Epoch 1810/2000, loss = 605.99, encoder_loss = 11.06, phi= tensor([0.3274]), var_u =1.0
#
# Epoch 1820/2000, loss = 596.70, encoder_loss = 10.08, phi= tensor([0.3278]), var_u =1.0
#
# Epoch 1830/2000, loss = 598.69, encoder_loss = 10.65, phi= tensor([0.3280]), var_u =1.0
#
# Epoch 1840/2000, loss = 599.72, encoder_loss = 10.69, phi= tensor([0.3287]), var_u =1.0
#
# Epoch 1850/2000, loss = 598.50, encoder_loss = 10.08, phi= tensor([0.3296]), var_u =1.0
#
# Epoch 1860/2000, loss = 600.59, encoder_loss = 10.46, phi= tensor([0.3303]), var_u =1.0
#
# Epoch 1870/2000, loss = 598.53, encoder_loss = 10.47, phi= tensor([0.3312]), var_u =1.0
#
# Epoch 1880/2000, loss = 601.91, encoder_loss = 8.70, phi= tensor([0.3319]), var_u =1.0
#
# Epoch 1890/2000, loss = 601.08, encoder_loss = 9.46, phi= tensor([0.3323]), var_u =1.0
#
# Epoch 1900/2000, loss = 596.82, encoder_loss = 10.35, phi= tensor([0.3326]), var_u =1.0
#
# Epoch 1910/2000, loss = 601.92, encoder_loss = 9.81, phi= tensor([0.3329]), var_u =1.0
#
# Epoch 1920/2000, loss = 599.36, encoder_loss = 9.73, phi= tensor([0.3337]), var_u =1.0
#
# Epoch 1930/2000, loss = 599.86, encoder_loss = 9.87, phi= tensor([0.3343]), var_u =1.0
#
# Epoch 1940/2000, loss = 601.05, encoder_loss = 9.33, phi= tensor([0.3351]), var_u =1.0
#
# Epoch 1950/2000, loss = 604.55, encoder_loss = 10.71, phi= tensor([0.3358]), var_u =1.0
#
# Epoch 1960/2000, loss = 600.54, encoder_loss = 10.76, phi= tensor([0.3361]), var_u =1.0
#
# Epoch 1970/2000, loss = 604.56, encoder_loss = 12.12, phi= tensor([0.3365]), var_u =1.0
#
# Epoch 1980/2000, loss = 604.04, encoder_loss = 9.79, phi= tensor([0.3370]), var_u =1.0
#
# Epoch 1990/2000, loss = 599.22, encoder_loss = 10.18, phi= tensor([0.3375]), var_u =1.0
#
# Epoch 2000/2000, loss = 602.54, encoder_loss = 11.86, phi= tensor([0.3375]), var_u =1.0

# %%
with torch.no_grad():
    zhat, uhat = gl.encoder(dat_true["x"], dat_true["y"])
    yhat = gl.decoder(dat_true["x"], zhat, uhat)

plt.scatter(dat_true["y"], yhat)
plt.plot([-20, 20], [-20, 20], color="red")

# %%
zhat = zhat*-1
plt.scatter(zhat, dat_true["z"])
plt.plot([-10, 10], [-10,10], color="red")

# %%
# print 12 randomly selected Z
index = np.random.choice(range(n), 12, replace=False)
fig, axs = plt.subplots(3, 4)

zhat= -zhat
fig.suptitle("Ztrue vs Zest across time")
for i in range(12):
    axs[i//4, i%4].plot(zhat[index[i],:,0]*-1)
    axs[i//4, i%4].plot(dat_true["z"][index[i],:, 0], color="red")

# %%
par_true = gl_true.decoder.parameters().__next__().detach().squeeze()
par_est = gl.decoder.parameters().__next__() .detach().squeeze()

# %%
plt.scatter(par_true, par_est)
plt.plot([-2,2], [2, -2])

# %% [markdown]
# ### Details on tensor products calculations
# We now show the details on the tensor products, for instance for computing `xb @ wx`. `xb` is of size `(n, T, q)` and `wx` is of size `(T, q, p)`. We want a result of size `(n, T, p)`. First we add a dimension for `xb`:
#
# `xb.unsqueeze(2)` which yields a dimensions of `(n, T, 1, q)`
#
# which we then multiply by `wz`:
#
# `(n, T, 1, q) @ (1, q, p)` -> `(n, T, 1, p)`
#
# where the first dimension of `wx` has been broadcasted.
#
# Finally, we squeeze to obtain `(n, T, p)`.
